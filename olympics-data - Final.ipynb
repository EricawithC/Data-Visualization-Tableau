# %% [markdown]
# # Exploring the Olympics dataset

# %%
import pandas as pd
import numpy as np

# %%
# Read in the data set
olympics = pd.read_csv('Dataset/athlete_events.csv')
olympics.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# ### Data exploration

# %% [markdown]
# #### 1) Missing Values
# Printing column wise missing values.

# %%
print(olympics.isnull().sum())
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %% [markdown]
# We find that height, weight and Age have a lot of missing values. Medals have a NaN in about 2,31,333 rows. These can be explained since not all participating athletes would win medals.

# %%
#Replacing these missing values by 'Did not win' or 'DNW'

olympics['Medal'].fillna('DNW', inplace = True)

# %%
# As expected the NaNs in the 'Medal' column disappear!
print(olympics.isnull().sum())
# Out:
# ID            0
# Name          0
# Sex           0
# Age        9474
# Height    60171
# Weight    62875
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal         0
# dtype: int64

# %%
#Dropping duplicates
print(olympics.loc[:, ['NOC', 'Team']].drop_duplicates()['NOC'].value_counts().head())
# Out:
# FRA    160
# USA     97
# GBR     96
# SWE     52
# NOR     46
# Name: NOC, dtype: int64

# %%
# Cleaning and renaming dataset country_definitions
noc_country = pd.read_csv('Dataset/country_definitions.csv')
noc_country.drop('notes', axis = 1 , inplace = True)
noc_country.rename(columns = {'region':'Country'}, inplace = True)

noc_country.head()
# Out:
#    NOC      Country
# 0  AFG  Afghanistan
# 1  AHO      Curacao
# 2  ALB      Albania
# 3  ALG      Algeria
# 4  AND      Andorra

# %%
# merging country_definitions and athlete_events on NOC
olympics_merge = olympics.merge(noc_country,
                                left_on = 'NOC',
                                right_on = 'NOC',
                                how = 'left')
olympics_merge
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal  \
# 0          Basketball               Basketball Men's Basketball   DNW
# 1                Judo              Judo Men's Extra-Lightweight   DNW
# 2            Football                   Football Men's Football   DNW
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   DNW
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   DNW
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   DNW
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   DNW
# 271114      Bobsleigh                      Bobsleigh Men's Four   DNW
# 271115      Bobsleigh                      Bobsleigh Men's Four   DNW
#
#             Country
# 0             China
# 1             China
# 2           Denmark
# 3           Denmark
# 4       Netherlands
# ...             ...
# 271111       Poland
# 271112       Poland
# 271113       Poland
# 271114       Poland
# 271115       Poland
#
# [271116 rows x 16 columns]

# %%
# Dropping duplicates
olympics_merge.loc[olympics_merge['Country'].isnull(),['NOC', 'Team']].drop_duplicates()
olympics_merge
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal  \
# 0          Basketball               Basketball Men's Basketball   DNW
# 1                Judo              Judo Men's Extra-Lightweight   DNW
# 2            Football                   Football Men's Football   DNW
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   DNW
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   DNW
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   DNW
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   DNW
# 271114      Bobsleigh                      Bobsleigh Men's Four   DNW
# 271115      Bobsleigh                      Bobsleigh Men's Four   DNW
#
#             Country
# 0             China
# 1             China
# 2           Denmark
# 3           Denmark
# 4       Netherlands
# ...             ...
# 271111       Poland
# 271112       Poland
# 271113       Poland
# 271114       Poland
# 271115       Poland
#
# [271116 rows x 16 columns]

# %% [markdown]
# Adjusting values relating the NOC column.
# Put correct values in some countries:\
#     1. SGP - Singapore
#     2. ROT - Refugee Olympic Athletes
#     3. UNK - Unknown
#     4. TUV - Tuvalu

# %%
# Replace missing Teams by the values above.
#olympics_merge.loc[olympics_merge['Country'].isnull(), ['Country']] = olympics_merge['Team']

olympics_merge['Country'] = np.where(olympics_merge['NOC']=='SGP', 'Singapore', olympics_merge['Country'])
olympics_merge['Country'] = np.where(olympics_merge['NOC']=='ROT', 'Refugee Olympic Athletes', olympics_merge['Country'])
olympics_merge['Country'] = np.where(olympics_merge['NOC']=='UNK', 'Unknown', olympics_merge['Country'])
olympics_merge['Country'] = np.where(olympics_merge['NOC']=='TUV', 'Tuvalu', olympics_merge['Country'])

olympics_merge
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal  \
# 0          Basketball               Basketball Men's Basketball   DNW
# 1                Judo              Judo Men's Extra-Lightweight   DNW
# 2            Football                   Football Men's Football   DNW
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   DNW
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   DNW
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   DNW
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   DNW
# 271114      Bobsleigh                      Bobsleigh Men's Four   DNW
# 271115      Bobsleigh                      Bobsleigh Men's Four   DNW
#
#             Country
# 0             China
# 1             China
# 2           Denmark
# 3           Denmark
# 4       Netherlands
# ...             ...
# 271111       Poland
# 271112       Poland
# 271113       Poland
# 271114       Poland
# 271115       Poland
#
# [271116 rows x 16 columns]

# %% [markdown]
# ### Merge GDP data

# %%
w_gdp = pd.read_csv('Dataset/world_gdp.csv', skiprows = 3)

# Remove unnecessary columns
w_gdp.drop(['Indicator Name', 'Indicator Code'], axis = 1, inplace = True)

w_gdp = pd.melt(w_gdp, id_vars = ['Country Name', 'Country Code'], var_name = 'Year', value_name = 'GDP')

# convert the year column to numeric
w_gdp['Year'] = pd.to_numeric(w_gdp['Year'])

w_gdp.head()
# Out:
#      Country Name Country Code  Year           GDP
# 0     Afghanistan          AFG  1960  5.377778e+08
# 1         Albania          ALB  1960           NaN
# 2         Algeria          DZA  1960  2.723649e+09
# 3  American Samoa          ASM  1960           NaN
# 4         Andorra          AND  1960           NaN

# %%
# Merge to get country code
olympics_merge_ccode = olympics_merge.merge(w_gdp[['Country Name', 'Country Code']].drop_duplicates(),
                                            left_on = 'Country',
                                            right_on = 'Country Name',
                                            how = 'left')

olympics_merge_ccode.drop('Country Name', axis = 1, inplace = True)

# Merge to get gdp too
olympics_merge_gdp = olympics_merge_ccode.merge(w_gdp,
                                                left_on = ['Country Code', 'Year'],
                                                right_on = ['Country Code', 'Year'],
                                                how = 'left')

olympics_merge_gdp.drop('Country Name', axis = 1, inplace = True)

olympics_merge_gdp
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal  \
# 0          Basketball               Basketball Men's Basketball   DNW
# 1                Judo              Judo Men's Extra-Lightweight   DNW
# 2            Football                   Football Men's Football   DNW
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   DNW
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   DNW
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   DNW
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   DNW
# 271114      Bobsleigh                      Bobsleigh Men's Four   DNW
# 271115      Bobsleigh                      Bobsleigh Men's Four   DNW
#
#             Country Country Code           GDP
# 0             China          CHN  4.269160e+11
# 1             China          CHN  8.560550e+12
# 2           Denmark          DNK           NaN
# 3           Denmark          DNK           NaN
# 4       Netherlands          NLD  2.585680e+11
# ...             ...          ...           ...
# 271111       Poland          POL           NaN
# 271112       Poland          POL  5.450760e+11
# 271113       Poland          POL  5.450760e+11
# 271114       Poland          POL  1.743880e+11
# 271115       Poland          POL  1.986810e+11
#
# [271116 rows x 18 columns]

# %% [markdown]
# ### Merge population data

# %%
# Read in the population data
w_pop = pd.read_csv('Dataset/population_ADA.csv')

w_pop["geo"]=w_pop["geo"].str.upper()
olympics_complete = olympics_merge_gdp.merge(w_pop,
                                            left_on = ['NOC', 'Year'],
                                            right_on= ['geo', 'time'],
                                            how = 'left')

olympics_complete.drop(["geo","name", "time"], axis = 1, inplace = True)

olympics_complete
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal  \
# 0          Basketball               Basketball Men's Basketball   DNW
# 1                Judo              Judo Men's Extra-Lightweight   DNW
# 2            Football                   Football Men's Football   DNW
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   DNW
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   DNW
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   DNW
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   DNW
# 271114      Bobsleigh                      Bobsleigh Men's Four   DNW
# 271115      Bobsleigh                      Bobsleigh Men's Four   DNW
#
#             Country Country Code           GDP    Population
# 0             China          CHN  4.269160e+11  1.183813e+09
# 1             China          CHN  8.560550e+12  1.366561e+09
# 2           Denmark          DNK           NaN           NaN
# 3           Denmark          DNK           NaN           NaN
# 4       Netherlands          NLD  2.585680e+11           NaN
# ...             ...          ...           ...           ...
# 271111       Poland          POL           NaN  3.422971e+07
# 271112       Poland          POL  5.450760e+11  3.858187e+07
# 271113       Poland          POL  5.450760e+11  3.858187e+07
# 271114       Poland          POL  1.743880e+11  3.837999e+07
# 271115       Poland          POL  1.986810e+11  3.864748e+07
#
# [271116 rows x 19 columns]

# %%
olympics_complete.isnull().sum()
# Out:
# ID                  0
# Name                0
# Sex                 0
# Age              9474
# Height          60171
# Weight          62875
# Team                0
# NOC                 0
# Games               0
# Year                0
# Season              0
# City                0
# Sport               0
# Event               0
# Medal               0
# Country             0
# Country Code     1397
# GDP             86925
# Population      74637
# dtype: int64

# %% [markdown]
# We have observed that in past years (especially before 1960) there are many missing values. However to guarantee more interactivity and a time-wise analysis, we decided to not filter the time directly on the dataset.

# %%
# Reset row indices
olympics_complete = olympics_complete.reset_index()
olympics_complete
# Out:
#          index      ID                      Name Sex   Age  Height  Weight  \
# 0            0       1                 A Dijiang   M  24.0   180.0    80.0
# 1            1       2                  A Lamusi   M  23.0   170.0    60.0
# 2            2       3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            3       4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            4       5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...     ...                       ...  ..   ...     ...     ...
# 271111  271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal  \
# 0          Basketball               Basketball Men's Basketball   DNW
# 1                Judo              Judo Men's Extra-Lightweight   DNW
# 2            Football                   Football Men's Football   DNW
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   DNW
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   DNW
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   DNW
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   DNW
# 271114      Bobsleigh                      Bobsleigh Men's Four   DNW
# 271115      Bobsleigh                      Bobsleigh Men's Four   DNW
#
#             Country Country Code           GDP    Population
# 0             China          CHN  4.269160e+11  1.183813e+09
# 1             China          CHN  8.560550e+12  1.366561e+09
# 2           Denmark          DNK           NaN           NaN
# 3           Denmark          DNK           NaN           NaN
# 4       Netherlands          NLD  2.585680e+11           NaN
# ...             ...          ...           ...           ...
# 271111       Poland          POL           NaN  3.422971e+07
# 271112       Poland          POL  5.450760e+11  3.858187e+07
# 271113       Poland          POL  5.450760e+11  3.858187e+07
# 271114       Poland          POL  1.743880e+11  3.837999e+07
# 271115       Poland          POL  1.986810e+11  3.864748e+07
#
# [271116 rows x 20 columns]

# %%
#Download file 

olympics_complete.to_csv("Dataset5.0.csv", index=False)
